# %% [markdown]
# Since the dataset is now organized by label folders (Bitumin, Block, Concrete, Kankar) and each folder contains chunked CSVs, you're set for training a deep learning model. Let’s go step-by-step for building the model from this structure.

# %% [markdown]
# ## Step 1: Load and Prepare the Data

# %%
import os
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

# %% [markdown]
# # Harshit_Preprocessed_Data-CS200U

# %%
# Define base directory
base_dir = "Dataset/Harshit_Preprocessed_Data-CS200"

# Map folder names to class labels
label_map = {
    "Bitumin": 0,
    "Block": 1,
    "Concrete": 2,
    "Kanker": 3
}

X = []
y = []

# %%
# Iterate through each folder
for label_name, label in label_map.items():
    folder_path = os.path.join(base_dir, label_name)
    for file_name in os.listdir(folder_path):
        if file_name.endswith(".csv"):
            file_path = os.path.join(folder_path, file_name)
            try:
                df = pd.read_csv(file_path)
                # Ensure it has 200 rows and required columns
                if df.shape[0] == 200:
                    sample = df[['X_Acc', 'Y_Acc', 'Z_Acc', 'X_Gyro', 'Y_Gyro', 'Z_Gyro']].values
                    X.append(sample)
                    y.append(label)
            except Exception as e:
                print(f"Error reading {file_path}: {e}")

X = np.array(X)  # Shape: (samples, 200, 6)
y = np.array(y)

print("Loaded data shape:", X.shape, y.shape)
# Out:
# Loaded data shape: (1403, 200, 6) (1403,)

# %% [markdown]
# ## Step 2: Normalize and Split the Data

# %%
# Flatten and normalize
X_flat = X.reshape(-1, X.shape[-1])
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X_flat).reshape(X.shape)

# Train-test split
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.2, random_state=42, stratify=y)

# %% [markdown]
# ## Step 3: Define the LSTM Model

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout

# %%
model = Sequential([
    LSTM(64, return_sequences=True, input_shape=(200, 6)),
    Dropout(0.3),
    LSTM(32),
    Dense(32, activation='relu'),
    Dropout(0.3),
    Dense(4, activation='softmax')  # 4 output classes
])

model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
model.summary()
# Out:
# c:\Python312\Lib\site-packages\keras\src\layers\rnn\rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ lstm_2 (LSTM)                   │ (None, 200, 64)        │        18,176 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 200, 64)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_3 (LSTM)                   │ (None, 32)             │        12,416 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 32)             │         1,056 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_3 (Dropout)             │ (None, 32)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 4)              │           132 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 31,780 (124.14 KB)
#  Trainable params: 31,780 (124.14 KB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# ## Step 4: Train the Model

# %%
history = model.fit(X_train, y_train, epochs=30, batch_size=32, validation_data=(X_test, y_test))
# Out:
# Epoch 1/30
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 10s 123ms/step - accuracy: 0.3236 - loss: 1.3705 - val_accuracy: 0.4306 - val_loss: 1.2658
# Epoch 2/30
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 4s 113ms/step - accuracy: 0.4054 - loss: 1.2417 - val_accuracy: 0.4804 - val_loss: 1.0707
# Epoch 3/30
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 4s 114ms/step - accuracy: 0.5022 - loss: 1.0666 - val_accuracy: 0.5374 - val_loss: 0.9716
# Epoch 4/30
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 5s 128ms/step - accuracy: 0.5751 - loss: 0.9785 - val_accuracy: 0.6085 - val_loss: 0.8918
# Epoch 5/30
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 4s 105ms/step - accuracy: 0.6480 - loss: 0.8825 - val_accuracy: 0.6655 - val_loss: 0.7904
# Epoch 6/30
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 4s 108ms/step - accuracy: 0.6429 - loss: 0.8178 - val_accuracy: 0.6797 - val_loss: 0.8272
# Epoch 7/30
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 4s 122ms/step - accuracy: 0.6344 - loss: 0.9184 - val_accuracy: 0.7224 - val_loss: 0.7198
# Epoch 8/30
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 4s 105ms/step - accuracy: 0.7242 - loss: 0.7163 - val_accuracy: 0.6335 - val_loss: 0.8459
# Epoch 9/30
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 4s 100ms/step - accuracy: 0.6802 - loss: 0.8219 - val_accuracy: 0.7651 - val_loss: 0.8023
# Epoch 10/30
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 90ms/step - accuracy: 0.7116 - loss: 0.7622 - val_accuracy: 0.8114 - val_loss: 0.6129
# Epoch 11/30
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 94ms/step - accuracy: 0.7885 - loss: 0.5336 - val_accuracy: 0.8719 - val_loss: 0.4957
# Epoch 12/30
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 94ms/step - accuracy: 0.7769 - loss: 0.7090 - val_accuracy: 0.7331 - val_loss: 0.7702
# Epoch 13/30
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 4s 103ms/step - accuracy: 0.6421 - loss: 0.9076 - val_accuracy: 0.7580 - val_loss: 0.6685
# Epoch 14/30
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 4s 114ms/step - accuracy: 0.7633 - loss: 0.6911 - val_accuracy: 0.7616 - val_loss: 0.7388
# Epoch 15/30
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 4s 114ms/step - accuracy: 0.7902 - loss: 0.6219 - val_accuracy: 0.8541 - val_loss: 0.4597
# Epoch 16/30
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 5s 119ms/step - accuracy: 0.8705 - loss: 0.4596 - val_accuracy: 0.8577 - val_loss: 0.5195
# Epoch 17/30
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 4s 113ms/step - accuracy: 0.8975 - loss: 0.3751 - val_accuracy: 0.8754 - val_loss: 0.4584
# Epoch 18/30
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 5s 134ms/step - accuracy: 0.8128 - loss: 0.5716 - val_accuracy: 0.7900 - val_loss: 0.6714
# Epoch 19/30
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 5s 132ms/step - accuracy: 0.8191 - loss: 0.5640 - val_accuracy: 0.8363 - val_loss: 0.4860
# Epoch 20/30
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 4s 108ms/step - accuracy: 0.8321 - loss: 0.5357 - val_accuracy: 0.7224 - val_loss: 0.7243
# Epoch 21/30
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 4s 122ms/step - accuracy: 0.7822 - loss: 0.6230 - val_accuracy: 0.8292 - val_loss: 0.4788
# Epoch 22/30
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 4s 104ms/step - accuracy: 0.8449 - loss: 0.4492 - val_accuracy: 0.8648 - val_loss: 0.3901
# Epoch 23/30
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 5s 133ms/step - accuracy: 0.8959 - loss: 0.3588 - val_accuracy: 0.8790 - val_loss: 0.4081
# Epoch 24/30
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 4s 117ms/step - accuracy: 0.9071 - loss: 0.3320 - val_accuracy: 0.8790 - val_loss: 0.3797
# Epoch 25/30
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 5s 119ms/step - accuracy: 0.9017 - loss: 0.3377 - val_accuracy: 0.8612 - val_loss: 0.3961
# Epoch 26/30
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 4s 114ms/step - accuracy: 0.8710 - loss: 0.3645 - val_accuracy: 0.9004 - val_loss: 0.3903
# Epoch 27/30
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 4s 118ms/step - accuracy: 0.8575 - loss: 0.4917 - val_accuracy: 0.9075 - val_loss: 0.3934
# Epoch 28/30
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 5s 122ms/step - accuracy: 0.9190 - loss: 0.3032 - val_accuracy: 0.9110 - val_loss: 0.3623
# Epoch 29/30
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 5s 128ms/step - accuracy: 0.9280 - loss: 0.2408 - val_accuracy: 0.7972 - val_loss: 0.5086
# Epoch 30/30
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 4s 113ms/step - accuracy: 0.8564 - loss: 0.3754 - val_accuracy: 0.9004 - val_loss: 0.3808

# %% [markdown]
# ## Step 5: Evaluate and Visualize Performance

# %%
import matplotlib.pyplot as plt

# Accuracy plot
plt.plot(history.history['accuracy'], label='Train Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.title('Model Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# Evaluate
loss, accuracy = model.evaluate(X_test, y_test)
print(f"Test Accuracy: {accuracy:.2f}")
# Out:
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.8905 - loss: 0.4155
# Test Accuracy: 0.90

# %% [markdown]
# ## Confusion Matrix

# %%
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay

y_pred = model.predict(X_test)
y_pred_classes = np.argmax(y_pred, axis=1)

cm = confusion_matrix(y_test, y_pred_classes)
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=label_map.keys())
disp.plot(cmap='Blues')
plt.show()
# Out:
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 139ms/step

# %% [markdown]
# ## Save the Trained Model

# %%
model.save("Models/Model_Architecture(CS200-U).h5")
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %% [markdown]
# ## Full Real-Time Sample Inference Code:

# %%
from tensorflow.keras.models import load_model
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler

# Load trained model and scaler
model = load_model("Models/Model_Architecture(CS200-U).h5")

# Recreate scaler from training (you may save and load if needed)
# For now, assuming you have same StandardScaler object as training
scaler = StandardScaler()

# Use all training data to fit the scaler again
X_flat = X.reshape(-1, X.shape[-1])
scaler.fit(X_flat)
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# StandardScaler()

# %%
# Load real-time test sample
sample_df = pd.read_csv(r"Dataset\Harshit_Preprocessed_Data-CS200\Bitumin\001_Abj_Bitumin_1_12-2_part_001.csv")
sample = sample_df[['X_Acc', 'Y_Acc', 'Z_Acc', 'X_Gyro', 'Y_Gyro', 'Z_Gyro']].values
sample_scaled = scaler.transform(sample).reshape(1, 200, 6)

# Predict
prediction = model.predict(sample_scaled)
predicted_class = np.argmax(prediction)
reverse_map = {v: k for k, v in label_map.items()}
print("Predicted Road Type:", reverse_map[predicted_class])
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 709ms/step
# Predicted Road Type: Bitumin
