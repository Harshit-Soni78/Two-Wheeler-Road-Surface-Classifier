# %% [markdown]
# Since the dataset is now organized by label folders (Bitumin, Block, Concrete, Kankar) and each folder contains chunked CSVs, you're set for training a deep learning model. Let’s go step-by-step for building the model from this structure.

# %% [markdown]
# ## Step 1: Load and Prepare the Data

# %%
import os
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

# %% [markdown]
# # Harshit_Preprocessed_Data-CS200E

# %%
# Define base directory
base_dir = "Dataset/Harshit_Preprocessed_Data-CS200 - (Equalize Data)"

# Map folder names to class labels
label_map = {
    "Bitumin": 0,
    "Block": 1,
    "Concrete": 2,
    "Kanker": 3
}

X = []
y = []

# %%
# Iterate through each folder
for label_name, label in label_map.items():
    folder_path = os.path.join(base_dir, label_name)
    for file_name in os.listdir(folder_path):
        if file_name.endswith(".csv"):
            file_path = os.path.join(folder_path, file_name)
            try:
                df = pd.read_csv(file_path)
                # Ensure it has 200 rows and required columns
                if df.shape[0] == 200:
                    sample = df[['X_Acc', 'Y_Acc', 'Z_Acc', 'X_Gyro', 'Y_Gyro', 'Z_Gyro']].values
                    X.append(sample)
                    y.append(label)
            except Exception as e:
                print(f"Error reading {file_path}: {e}")

X = np.array(X)  # Shape: (samples, 200, 6)
y = np.array(y)

print("Loaded data shape:", X.shape, y.shape)
# Out:
# Loaded data shape: (1004, 200, 6) (1004,)

# %% [markdown]
# ## Step 2: Normalize and Split the Data

# %%
# Flatten and normalize
X_flat = X.reshape(-1, X.shape[-1])
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X_flat).reshape(X.shape)

# Train-test split
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.2, random_state=42, stratify=y)

# %% [markdown]
# ## Step 3: Define the LSTM Model

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout

# %%
model = Sequential([
    LSTM(64, return_sequences=True, input_shape=(200, 6)),
    Dropout(0.3),
    LSTM(32),
    Dense(32, activation='relu'),
    Dropout(0.3),
    Dense(4, activation='softmax')  # 4 output classes
])

model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
model.summary()
# Out:
# c:\Python312\Lib\site-packages\keras\src\layers\rnn\rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Model: "sequential_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ lstm_4 (LSTM)                   │ (None, 200, 64)        │        18,176 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_4 (Dropout)             │ (None, 200, 64)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_5 (LSTM)                   │ (None, 32)             │        12,416 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_4 (Dense)                 │ (None, 32)             │         1,056 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_5 (Dropout)             │ (None, 32)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_5 (Dense)                 │ (None, 4)              │           132 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 31,780 (124.14 KB)
#  Trainable params: 31,780 (124.14 KB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# ## Step 4: Train the Model

# %%
history = model.fit(X_train, y_train, epochs=30, batch_size=32, validation_data=(X_test, y_test))
# Out:
# Epoch 1/30
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 5s 92ms/step - accuracy: 0.2968 - loss: 1.3647 - val_accuracy: 0.4577 - val_loss: 1.2745
# Epoch 2/30
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 2s 87ms/step - accuracy: 0.4299 - loss: 1.2612 - val_accuracy: 0.4776 - val_loss: 1.1479
# Epoch 3/30
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 2s 92ms/step - accuracy: 0.4866 - loss: 1.1189 - val_accuracy: 0.6119 - val_loss: 0.9468
# Epoch 4/30
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 2s 82ms/step - accuracy: 0.5787 - loss: 0.9561 - val_accuracy: 0.6219 - val_loss: 0.9953
# Epoch 5/30
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 2s 85ms/step - accuracy: 0.5940 - loss: 0.9750 - val_accuracy: 0.5771 - val_loss: 0.9659
# Epoch 6/30
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - accuracy: 0.6279 - loss: 0.8838 - val_accuracy: 0.5771 - val_loss: 1.0129
# Epoch 7/30
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 3s 96ms/step - accuracy: 0.5780 - loss: 1.0117 - val_accuracy: 0.6119 - val_loss: 0.9089
# Epoch 8/30
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 2s 86ms/step - accuracy: 0.6760 - loss: 0.7982 - val_accuracy: 0.6517 - val_loss: 0.8548
# Epoch 9/30
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - accuracy: 0.7014 - loss: 0.7880 - val_accuracy: 0.6667 - val_loss: 0.7912
# Epoch 10/30
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 3s 100ms/step - accuracy: 0.6393 - loss: 0.8210 - val_accuracy: 0.6965 - val_loss: 0.7577
# Epoch 11/30
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 3s 105ms/step - accuracy: 0.7091 - loss: 0.7064 - val_accuracy: 0.6020 - val_loss: 0.8903
# Epoch 12/30
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 2s 79ms/step - accuracy: 0.7244 - loss: 0.7248 - val_accuracy: 0.6816 - val_loss: 0.7796
# Epoch 13/30
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 2s 86ms/step - accuracy: 0.7363 - loss: 0.7223 - val_accuracy: 0.6119 - val_loss: 0.7962
# Epoch 14/30
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 2s 77ms/step - accuracy: 0.7418 - loss: 0.7536 - val_accuracy: 0.7114 - val_loss: 0.7151
# Epoch 15/30
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 2s 82ms/step - accuracy: 0.6192 - loss: 1.0309 - val_accuracy: 0.5423 - val_loss: 1.1207
# Epoch 16/30
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 2s 82ms/step - accuracy: 0.5255 - loss: 1.0604 - val_accuracy: 0.6119 - val_loss: 0.9190
# Epoch 17/30
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 2s 91ms/step - accuracy: 0.6424 - loss: 0.8656 - val_accuracy: 0.6368 - val_loss: 0.8170
# Epoch 18/30
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - accuracy: 0.6433 - loss: 0.7635 - val_accuracy: 0.6070 - val_loss: 0.9091
# Epoch 19/30
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 2s 93ms/step - accuracy: 0.6380 - loss: 0.8087 - val_accuracy: 0.5771 - val_loss: 1.0096
# Epoch 20/30
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 3s 106ms/step - accuracy: 0.6033 - loss: 0.9000 - val_accuracy: 0.6070 - val_loss: 0.8739
# Epoch 21/30
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 3s 112ms/step - accuracy: 0.6571 - loss: 0.7455 - val_accuracy: 0.5771 - val_loss: 0.9855
# Epoch 22/30
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 3s 117ms/step - accuracy: 0.6205 - loss: 0.8852 - val_accuracy: 0.6766 - val_loss: 0.8166
# Epoch 23/30
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 3s 113ms/step - accuracy: 0.6505 - loss: 0.8003 - val_accuracy: 0.5672 - val_loss: 0.9167
# Epoch 24/30
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 4s 136ms/step - accuracy: 0.6103 - loss: 0.8743 - val_accuracy: 0.6368 - val_loss: 0.8056
# Epoch 25/30
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 3s 107ms/step - accuracy: 0.6758 - loss: 0.7154 - val_accuracy: 0.7214 - val_loss: 0.6589
# Epoch 26/30
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 3s 105ms/step - accuracy: 0.7393 - loss: 0.6336 - val_accuracy: 0.7313 - val_loss: 0.6356
# Epoch 27/30
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 3s 108ms/step - accuracy: 0.7164 - loss: 0.5935 - val_accuracy: 0.7562 - val_loss: 0.7262
# Epoch 28/30
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 3s 119ms/step - accuracy: 0.7573 - loss: 0.6191 - val_accuracy: 0.7612 - val_loss: 0.6420
# Epoch 29/30
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 3s 117ms/step - accuracy: 0.7527 - loss: 0.6040 - val_accuracy: 0.7612 - val_loss: 0.6421
# Epoch 30/30
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 3s 106ms/step - accuracy: 0.7562 - loss: 0.6572 - val_accuracy: 0.7711 - val_loss: 0.6740

# %% [markdown]
# ## Step 5: Evaluate and Visualize Performance

# %%
import matplotlib.pyplot as plt

# Accuracy plot
plt.plot(history.history['accuracy'], label='Train Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.title('Model Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# Evaluate
loss, accuracy = model.evaluate(X_test, y_test)
print(f"Test Accuracy: {accuracy:.2f}")
# Out:
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.7767 - loss: 0.6536
# Test Accuracy: 0.77

# %% [markdown]
# ## Confusion Matrix

# %%
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay

y_pred = model.predict(X_test)
y_pred_classes = np.argmax(y_pred, axis=1)

cm = confusion_matrix(y_test, y_pred_classes)
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=label_map.keys())
disp.plot(cmap='Blues')
plt.show()
# Out:
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 108ms/step

# %% [markdown]
# ## Save the Trained Model

# %%
model.save("Models/Model_Architecture(CS200-E).h5")
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %% [markdown]
# ## Full Real-Time Sample Inference Code:

# %%
from tensorflow.keras.models import load_model
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler

# Load trained model and scaler
model = load_model("Models/Model_Architecture(CS200-E).h5")

# Recreate scaler from training (you may save and load if needed)
# For now, assuming you have same StandardScaler object as training
scaler = StandardScaler()

# Use all training data to fit the scaler again
X_flat = X.reshape(-1, X.shape[-1])
scaler.fit(X_flat)
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# StandardScaler()

# %%
# Load real-time test sample
sample_df = pd.read_csv(r"Dataset\Harshit_Preprocessed_Data-CS200\Bitumin\001_Abj_Bitumin_1_12-2_part_001.csv")
sample = sample_df[['X_Acc', 'Y_Acc', 'Z_Acc', 'X_Gyro', 'Y_Gyro', 'Z_Gyro']].values
sample_scaled = scaler.transform(sample).reshape(1, 200, 6)

# Predict
prediction = model.predict(sample_scaled)
predicted_class = np.argmax(prediction)
reverse_map = {v: k for k, v in label_map.items()}
print("Predicted Road Type:", reverse_map[predicted_class])
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 500ms/step
# Predicted Road Type: Bitumin
