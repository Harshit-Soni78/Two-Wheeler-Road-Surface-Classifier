# %% [markdown]
# Since the dataset is now organized by label folders (Bitumin, Block, Concrete, Kankar) and each folder contains chunked CSVs, you're set for training a deep learning model. Let’s go step-by-step for building the model from this structure.

# %% [markdown]
# ## Step 1: Load and Prepare the Data

# %%
import os
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.utils.class_weight import compute_class_weight
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout, Bidirectional, BatchNormalization
import tensorflow as tf

# %% [markdown]
# # Harshit_Preprocessed_Data-CS250U

# %%
# Define base directory
base_dir = "Dataset/Harshit_Preprocessed_Data-CS250"

# Map folder names to class labels
label_map = {
    "Bitumin": 0,
    "Block": 1,
    "Concrete": 2,
    "Kanker": 3
}

X = []
y = []

# %%
# Iterate through each folder
for label_name, label in label_map.items():
    folder_path = os.path.join(base_dir, label_name)
    for file_name in os.listdir(folder_path):
        if file_name.endswith(".csv"):
            file_path = os.path.join(folder_path, file_name)
            try:
                df = pd.read_csv(file_path)
                # Ensure it has 200 rows and required columns
                if df.shape[0] == 250:
                    sample = df[['X_Acc', 'Y_Acc', 'Z_Acc', 'X_Gyro', 'Y_Gyro', 'Z_Gyro']].values
                    X.append(sample)
                    y.append(label)
            except Exception as e:
                print(f"Error reading {file_path}: {e}")

X = np.array(X)  # Shape: (samples, 200, 6)
y = np.array(y)

print("Loaded data shape:", X.shape, y.shape)
# Out:
# Loaded data shape: (1114, 250, 6) (1114,)

# %%
# --------------------- Class Weights ---------------------

class_labels = np.unique(y)
weights = compute_class_weight(class_weight='balanced', classes=class_labels, y=y)
class_weights = dict(zip(class_labels, weights))

# %%
# --------------------- Train-Test Split ---------------------

X_train, X_val, y_train, y_val = train_test_split(X, y, test_size=0.2, stratify=y, random_state=42)

# %%
# --------------------- Focal Loss Function ---------------------

def focal_loss(gamma=2., alpha=0.25):
    def focal_loss_fixed(y_true, y_pred):
        y_true = tf.one_hot(tf.cast(y_true, tf.int32), depth=4)
        y_pred = tf.clip_by_value(y_pred, 1e-7, 1 - 1e-7)
        cross_entropy = -y_true * tf.math.log(y_pred)
        weights = alpha * tf.math.pow(1 - y_pred, gamma)
        loss = weights * cross_entropy
        return tf.reduce_mean(tf.reduce_sum(loss, axis=1))
    return focal_loss_fixed

# %%
# --------------------- Model Architecture ---------------------

model = Sequential([
    Bidirectional(LSTM(128, return_sequences=True), input_shape=(250, 6)),
    BatchNormalization(),
    Dropout(0.4),

    Bidirectional(LSTM(64)),
    BatchNormalization(),
    Dropout(0.4),

    Dense(64, activation='relu'),
    Dropout(0.3),
    Dense(4, activation='softmax')
])

model.compile(
    optimizer='adam',
    loss=focal_loss(gamma=2., alpha=0.25),
    metrics=['accuracy']
)
# Out:
# c:\Python312\Lib\site-packages\keras\src\layers\rnn\bidirectional.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)

# %%
# --------------------- Train Model ---------------------

history = model.fit(
    X_train, y_train,
    validation_data=(X_val, y_val),
    epochs=50,
    batch_size=32,
    class_weight=class_weights,
    callbacks=[tf.keras.callbacks.EarlyStopping(patience=10, restore_best_weights=True)]
)
# Out:
# Epoch 1/50
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 38s 516ms/step - accuracy: 0.2550 - loss: 0.3789 - val_accuracy: 0.4350 - val_loss: 0.1702
# Epoch 2/50
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 12s 432ms/step - accuracy: 0.4628 - loss: 0.2324 - val_accuracy: 0.4843 - val_loss: 0.1562
# Epoch 3/50
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 12s 419ms/step - accuracy: 0.5169 - loss: 0.1905 - val_accuracy: 0.5561 - val_loss: 0.1385
# Epoch 4/50
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 15s 514ms/step - accuracy: 0.5698 - loss: 0.1512 - val_accuracy: 0.6009 - val_loss: 0.1247
# Epoch 5/50
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 13s 451ms/step - accuracy: 0.5914 - loss: 0.1302 - val_accuracy: 0.5874 - val_loss: 0.1185
# Epoch 6/50
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 10s 357ms/step - accuracy: 0.5987 - loss: 0.1332 - val_accuracy: 0.6323 - val_loss: 0.1113
# Epoch 7/50
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 12s 442ms/step - accuracy: 0.6517 - loss: 0.1148 - val_accuracy: 0.6816 - val_loss: 0.1020
# Epoch 8/50
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 15s 528ms/step - accuracy: 0.6627 - loss: 0.1108 - val_accuracy: 0.7265 - val_loss: 0.0985
# Epoch 9/50
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 14s 504ms/step - accuracy: 0.6683 - loss: 0.0996 - val_accuracy: 0.7085 - val_loss: 0.1015
# Epoch 10/50
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 15s 515ms/step - accuracy: 0.6929 - loss: 0.0913 - val_accuracy: 0.7085 - val_loss: 0.0951
# Epoch 11/50
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 14s 518ms/step - accuracy: 0.7197 - loss: 0.0858 - val_accuracy: 0.7130 - val_loss: 0.0911
# Epoch 12/50
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 21s 515ms/step - accuracy: 0.7284 - loss: 0.0724 - val_accuracy: 0.7130 - val_loss: 0.0856
# Epoch 13/50
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 18s 645ms/step - accuracy: 0.7451 - loss: 0.0766 - val_accuracy: 0.6951 - val_loss: 0.0928
# Epoch 14/50
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 17s 591ms/step - accuracy: 0.7604 - loss: 0.0671 - val_accuracy: 0.7534 - val_loss: 0.0824
# Epoch 15/50
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 15s 524ms/step - accuracy: 0.7820 - loss: 0.0607 - val_accuracy: 0.7937 - val_loss: 0.0677
# Epoch 16/50
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 13s 455ms/step - accuracy: 0.8211 - loss: 0.0559 - val_accuracy: 0.7758 - val_loss: 0.0654
# Epoch 17/50
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 18s 354ms/step - accuracy: 0.8298 - loss: 0.0473 - val_accuracy: 0.7713 - val_loss: 0.0733
# Epoch 18/50
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 9s 324ms/step - accuracy: 0.8341 - loss: 0.0472 - val_accuracy: 0.7758 - val_loss: 0.0827
# Epoch 19/50
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 7s 249ms/step - accuracy: 0.8431 - loss: 0.0409 - val_accuracy: 0.7758 - val_loss: 0.0844
# Epoch 20/50
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 7s 245ms/step - accuracy: 0.8464 - loss: 0.0356 - val_accuracy: 0.7892 - val_loss: 0.0794
# Epoch 21/50
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 7s 246ms/step - accuracy: 0.8635 - loss: 0.0418 - val_accuracy: 0.8072 - val_loss: 0.0729
# Epoch 22/50
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 7s 247ms/step - accuracy: 0.8948 - loss: 0.0296 - val_accuracy: 0.7892 - val_loss: 0.0678
# Epoch 23/50
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 7s 247ms/step - accuracy: 0.8870 - loss: 0.0327 - val_accuracy: 0.7937 - val_loss: 0.0705
# Epoch 24/50
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 7s 251ms/step - accuracy: 0.8654 - loss: 0.0303 - val_accuracy: 0.8386 - val_loss: 0.0643
# Epoch 25/50
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 10s 349ms/step - accuracy: 0.8719 - loss: 0.0310 - val_accuracy: 0.8296 - val_loss: 0.0761
# Epoch 26/50
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 8s 281ms/step - accuracy: 0.8800 - loss: 0.0323 - val_accuracy: 0.7803 - val_loss: 0.0711
# Epoch 27/50
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 9s 337ms/step - accuracy: 0.8963 - loss: 0.0272 - val_accuracy: 0.8251 - val_loss: 0.0703
# Epoch 28/50
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 9s 301ms/step - accuracy: 0.9011 - loss: 0.0251 - val_accuracy: 0.7937 - val_loss: 0.0646
# Epoch 29/50
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 9s 323ms/step - accuracy: 0.8827 - loss: 0.0227 - val_accuracy: 0.8251 - val_loss: 0.0628
# Epoch 30/50
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 10s 376ms/step - accuracy: 0.9196 - loss: 0.0209 - val_accuracy: 0.7578 - val_loss: 0.0856
# Epoch 31/50
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 9s 327ms/step - accuracy: 0.9233 - loss: 0.0181 - val_accuracy: 0.8251 - val_loss: 0.0656
# Epoch 32/50
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 8s 291ms/step - accuracy: 0.9124 - loss: 0.0196 - val_accuracy: 0.8565 - val_loss: 0.0642
# Epoch 33/50
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 7s 252ms/step - accuracy: 0.9360 - loss: 0.0147 - val_accuracy: 0.8475 - val_loss: 0.0613
# Epoch 34/50
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 9s 329ms/step - accuracy: 0.9404 - loss: 0.0188 - val_accuracy: 0.8296 - val_loss: 0.0789
# Epoch 35/50
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 10s 338ms/step - accuracy: 0.9288 - loss: 0.0178 - val_accuracy: 0.8475 - val_loss: 0.0713
# Epoch 36/50
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 12s 411ms/step - accuracy: 0.9532 - loss: 0.0139 - val_accuracy: 0.8520 - val_loss: 0.0687
# Epoch 37/50
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 20s 401ms/step - accuracy: 0.9574 - loss: 0.0101 - val_accuracy: 0.8341 - val_loss: 0.0793
# Epoch 38/50
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 9s 313ms/step - accuracy: 0.9428 - loss: 0.0163 - val_accuracy: 0.8251 - val_loss: 0.0827
# Epoch 39/50
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 7s 254ms/step - accuracy: 0.9269 - loss: 0.0169 - val_accuracy: 0.8610 - val_loss: 0.0699
# Epoch 40/50
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 11s 379ms/step - accuracy: 0.9555 - loss: 0.0111 - val_accuracy: 0.8430 - val_loss: 0.0707
# Epoch 41/50
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 11s 400ms/step - accuracy: 0.9513 - loss: 0.0145 - val_accuracy: 0.8655 - val_loss: 0.0806
# Epoch 42/50
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 11s 384ms/step - accuracy: 0.9349 - loss: 0.0143 - val_accuracy: 0.8296 - val_loss: 0.0850
# Epoch 43/50
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 7s 236ms/step - accuracy: 0.9670 - loss: 0.0123 - val_accuracy: 0.8341 - val_loss: 0.0862

# %% [markdown]
# ---

# %% [markdown]
# ## Step 5: Evaluate and Visualize Performance

# %%
import matplotlib.pyplot as plt

# Accuracy plot
plt.plot(history.history['accuracy'], label='Train Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.title('Model Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# Evaluate
loss, accuracy = model.evaluate(X_val, y_val)
print(f"Test Accuracy: {accuracy:.2f}")
# Out:
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 70ms/step - accuracy: 0.8316 - loss: 0.0830
# Test Accuracy: 0.85

# %% [markdown]
# ## Confusion Matrix

# %%
from sklearn.metrics import classification_report, confusion_matrix
import seaborn as sns
import matplotlib.pyplot as plt

# Predict
y_pred = np.argmax(model.predict(X), axis=1)

# Evaluation
print(classification_report(y, y_pred, target_names=label_map.keys()))

# Confusion Matrix
cm = confusion_matrix(y, y_pred)
sns.heatmap(cm, annot=True, cmap='Blues', xticklabels=label_map.keys(), yticklabels=label_map.keys())
plt.title("Confusion Matrix")
plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.show()
# Out:
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 5s 121ms/step
#               precision    recall  f1-score   support
#
#      Bitumin       0.97      0.97      0.97       399
#        Block       0.96      0.91      0.93       297
#     Concrete       0.90      0.97      0.93       220
#       Kanker       0.99      0.96      0.98       198
#
#     accuracy                           0.95      1114
#    macro avg       0.95      0.95      0.95      1114
# weighted avg       0.96      0.95      0.95      1114

# %%
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay

y_pred = model.predict(X_val)
y_pred_classes = np.argmax(y_pred, axis=1)

cm = confusion_matrix(y_val, y_pred_classes)
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=label_map.keys())
disp.plot(cmap='Blues')
plt.show()
# Out:
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 109ms/step

# %% [markdown]
# ## Save the Trained Model

# %%
model.save("Models/Model_Architecture(CS250-U)CB.h5")
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %% [markdown]
# ## Full Real-Time Sample Inference Code:

# %% [markdown]
# #### Step 1: Load the Required Libraries

# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras.models import load_model
from sklearn.preprocessing import StandardScaler
import pandas as pd
import os

# %% [markdown]
# #### Step 2: Load the Trained Model

# %%
# If you used focal loss, redefine it before loading
def focal_loss(gamma=2., alpha=0.25):
    def focal_loss_fixed(y_true, y_pred):
        epsilon = tf.keras.backend.epsilon()
        y_pred = tf.clip_by_value(y_pred, epsilon, 1. - epsilon)
        cross_entropy = -y_true * tf.math.log(y_pred)
        weight = alpha * tf.pow(1 - y_pred, gamma)
        loss = weight * cross_entropy
        return tf.reduce_sum(loss, axis=1)
    return focal_loss_fixed

# Load model
model = load_model('Models/Model_Architecture(CS250-U)CB.h5', custom_objects={'focal_loss_fixed': focal_loss()})
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.

# %% [markdown]
# #### Step 3: Load and Prepare Real-Time or Test Data

# %%
# Example: Path to one of your 200-row test CSVs
test_file_path = r"Dataset\Harshit_Preprocessed_Data-CS250\Block\001_Abj_Block_10_12-2_part_001.csv"  # replace with your actual path

# Load CSV
df_test = pd.read_csv(test_file_path)

# Extract only numeric columns (assumes sensor data are only numeric)
X_test = df_test[['X_Acc', 'Y_Acc', 'Z_Acc', 'X_Gyro', 'Y_Gyro', 'Z_Gyro']].values

# Standardize using same scaler used during training (Assuming fit on full training set)
scaler = StandardScaler()
X_test_scaled = scaler.fit_transform(X_test)

# Reshape for LSTM [samples, time_steps, features]
X_test_scaled = X_test_scaled.reshape(1, X_test_scaled.shape[0], X_test_scaled.shape[1])

# %% [markdown]
# #### Step 4: Make Prediction

# %%
# Make prediction
pred_probs = model.predict(X_test_scaled)
pred_class = np.argmax(pred_probs)

# Mapping label index to actual class names
label_map = {0: 'Bitumin', 1: 'Block', 2: 'Concrete', 3: 'Kankar'}
print("Predicted Road Type:", label_map[pred_class])
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 433ms/step
# Predicted Road Type: Kankar

# %% [markdown]
# ----

# %% [markdown]
# # Load TFLite Model (for mobile testing)

# %%
# Convert to TFLite
converter = tf.lite.TFLiteConverter.from_keras_model(model)
tflite_model = converter.convert()
with open("road_type_classifier.tflite", "wb") as f:
    f.write(tflite_model)

print("Model and TFLite version saved successfully.")

# %%
# Load the TFLite model
interpreter = tf.lite.Interpreter(model_path="road_classifier_model.tflite")
interpreter.allocate_tensors()

# Get input and output tensors
input_details = interpreter.get_input_details()
output_details = interpreter.get_output_details()

# Prepare input
input_data = X_test_scaled.astype(np.float32)

# Run inference
interpreter.set_tensor(input_details[0]['index'], input_data)
interpreter.invoke()

# Get prediction
output_data = interpreter.get_tensor(output_details[0]['index'])
predicted_class = np.argmax(output_data)
print("TFLite Predicted Road Type:", label_map[predicted_class])
