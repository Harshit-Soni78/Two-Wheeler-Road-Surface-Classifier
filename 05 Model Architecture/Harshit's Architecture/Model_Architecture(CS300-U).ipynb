# %% [markdown]
# Since the dataset is now organized by label folders (Bitumin, Block, Concrete, Kankar) and each folder contains chunked CSVs, you're set for training a deep learning model. Let’s go step-by-step for building the model from this structure.

# %% [markdown]
# ## Step 1: Load and Prepare the Data

# %%
import os
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

# %% [markdown]
# # Harshit_Preprocessed_Data-CS300U

# %%
# Define base directory
base_dir = "Dataset/Harshit_Preprocessed_Data-CS300"

# Map folder names to class labels
label_map = {
    "Bitumin": 0,
    "Block": 1,
    "Concrete": 2,
    "Kanker": 3
}

X = []
y = []

# %%
# Iterate through each folder
for label_name, label in label_map.items():
    folder_path = os.path.join(base_dir, label_name)
    for file_name in os.listdir(folder_path):
        if file_name.endswith(".csv"):
            file_path = os.path.join(folder_path, file_name)
            try:
                df = pd.read_csv(file_path)
                # Ensure it has 200 rows and required columns
                if df.shape[0] == 300:
                    sample = df[['X_Acc', 'Y_Acc', 'Z_Acc', 'X_Gyro', 'Y_Gyro', 'Z_Gyro']].values
                    X.append(sample)
                    y.append(label)
            except Exception as e:
                print(f"Error reading {file_path}: {e}")

X = np.array(X)  # Shape: (samples, 200, 6)
y = np.array(y)

print("Loaded data shape:", X.shape, y.shape)
# Out:
# Loaded data shape: (922, 300, 6) (922,)

# %% [markdown]
# ## Step 2: Normalize and Split the Data

# %%
# Flatten and normalize
X_flat = X.reshape(-1, X.shape[-1])
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X_flat).reshape(X.shape)

# Train-test split
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.2, random_state=42, stratify=y)

# %% [markdown]
# ## Step 3: Define the LSTM Model

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout

# %%
model = Sequential([
    LSTM(64, return_sequences=True, input_shape=(300, 6)),
    Dropout(0.3),
    LSTM(32),
    Dense(32, activation='relu'),
    Dropout(0.3),
    Dense(4, activation='softmax')  # 4 output classes
])

model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
model.summary()
# Out:
# c:\Python312\Lib\site-packages\keras\src\layers\rnn\rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ lstm (LSTM)                     │ (None, 300, 64)        │        18,176 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 300, 64)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_1 (LSTM)                   │ (None, 32)             │        12,416 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 32)             │         1,056 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 32)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 4)              │           132 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 31,780 (124.14 KB)
#  Trainable params: 31,780 (124.14 KB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# ## Step 4: Train the Model

# %%
history = model.fit(X_train, y_train, epochs=30, batch_size=32, validation_data=(X_test, y_test))
# Out:
# Epoch 1/30
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 11s 195ms/step - accuracy: 0.3079 - loss: 1.3717 - val_accuracy: 0.3622 - val_loss: 1.3294
# Epoch 2/30
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 3s 144ms/step - accuracy: 0.3534 - loss: 1.3199 - val_accuracy: 0.3568 - val_loss: 1.2923
# Epoch 3/30
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 3s 132ms/step - accuracy: 0.3879 - loss: 1.2486 - val_accuracy: 0.4108 - val_loss: 1.1500
# Epoch 4/30
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 3s 136ms/step - accuracy: 0.3742 - loss: 1.2122 - val_accuracy: 0.3676 - val_loss: 1.2223
# Epoch 5/30
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 4s 157ms/step - accuracy: 0.3619 - loss: 1.2438 - val_accuracy: 0.3946 - val_loss: 1.2051
# Epoch 6/30
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 4s 152ms/step - accuracy: 0.4040 - loss: 1.2472 - val_accuracy: 0.3892 - val_loss: 1.2673
# Epoch 7/30
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 4s 154ms/step - accuracy: 0.4372 - loss: 1.2256 - val_accuracy: 0.4216 - val_loss: 1.2064
# Epoch 8/30
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 3s 142ms/step - accuracy: 0.4999 - loss: 1.1528 - val_accuracy: 0.4541 - val_loss: 1.1947
# Epoch 9/30
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 4s 147ms/step - accuracy: 0.4742 - loss: 1.1851 - val_accuracy: 0.4378 - val_loss: 1.1686
# Epoch 10/30
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 4s 146ms/step - accuracy: 0.5209 - loss: 1.1410 - val_accuracy: 0.4541 - val_loss: 1.1427
# Epoch 11/30
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 3s 129ms/step - accuracy: 0.4955 - loss: 1.1445 - val_accuracy: 0.5405 - val_loss: 1.0394
# Epoch 12/30
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 3s 128ms/step - accuracy: 0.5675 - loss: 1.0164 - val_accuracy: 0.6486 - val_loss: 0.9090
# Epoch 13/30
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 3s 124ms/step - accuracy: 0.6443 - loss: 0.8638 - val_accuracy: 0.6973 - val_loss: 0.8941
# Epoch 14/30
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 3s 129ms/step - accuracy: 0.6505 - loss: 0.9700 - val_accuracy: 0.6865 - val_loss: 0.8176
# Epoch 15/30
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 3s 123ms/step - accuracy: 0.6256 - loss: 0.9627 - val_accuracy: 0.6216 - val_loss: 1.0273
# Epoch 16/30
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 3s 124ms/step - accuracy: 0.5854 - loss: 1.1216 - val_accuracy: 0.4919 - val_loss: 1.1914
# Epoch 17/30
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 3s 123ms/step - accuracy: 0.5035 - loss: 1.2113 - val_accuracy: 0.5243 - val_loss: 1.1182
# Epoch 18/30
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 3s 130ms/step - accuracy: 0.5606 - loss: 1.1169 - val_accuracy: 0.5514 - val_loss: 1.0417
# Epoch 19/30
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 3s 131ms/step - accuracy: 0.5989 - loss: 1.0488 - val_accuracy: 0.5676 - val_loss: 0.9792
# Epoch 20/30
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 3s 125ms/step - accuracy: 0.6043 - loss: 0.9902 - val_accuracy: 0.6000 - val_loss: 0.9134
# Epoch 21/30
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 3s 125ms/step - accuracy: 0.6069 - loss: 0.9675 - val_accuracy: 0.6486 - val_loss: 0.8402
# Epoch 22/30
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 3s 126ms/step - accuracy: 0.6667 - loss: 0.8778 - val_accuracy: 0.6541 - val_loss: 0.8103
# Epoch 23/30
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 3s 128ms/step - accuracy: 0.6913 - loss: 0.8400 - val_accuracy: 0.7027 - val_loss: 0.7113
# Epoch 24/30
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 3s 128ms/step - accuracy: 0.6941 - loss: 0.8261 - val_accuracy: 0.5838 - val_loss: 1.0515
# Epoch 25/30
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 4s 147ms/step - accuracy: 0.5354 - loss: 1.0916 - val_accuracy: 0.6378 - val_loss: 0.9118
# Epoch 26/30
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 4s 148ms/step - accuracy: 0.6233 - loss: 0.9057 - val_accuracy: 0.6324 - val_loss: 0.8451
# Epoch 27/30
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 3s 144ms/step - accuracy: 0.6735 - loss: 0.8043 - val_accuracy: 0.6541 - val_loss: 0.7693
# Epoch 28/30
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 3s 139ms/step - accuracy: 0.6651 - loss: 0.8058 - val_accuracy: 0.7243 - val_loss: 0.7074
# Epoch 29/30
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 3s 139ms/step - accuracy: 0.7057 - loss: 0.7460 - val_accuracy: 0.7622 - val_loss: 0.6639
# Epoch 30/30
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 3s 136ms/step - accuracy: 0.7662 - loss: 0.6809 - val_accuracy: 0.7459 - val_loss: 0.6073

# %% [markdown]
# ## Step 5: Evaluate and Visualize Performance

# %%
import matplotlib.pyplot as plt

# Accuracy plot
plt.plot(history.history['accuracy'], label='Train Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.title('Model Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# Evaluate
loss, accuracy = model.evaluate(X_test, y_test)
print(f"Test Accuracy: {accuracy:.2f}")
# Out:
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.7606 - loss: 0.5850
# Test Accuracy: 0.75

# %% [markdown]
# ## Confusion Matrix

# %%
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay

y_pred = model.predict(X_test)
y_pred_classes = np.argmax(y_pred, axis=1)

cm = confusion_matrix(y_test, y_pred_classes)
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=label_map.keys())
disp.plot(cmap='Blues')
plt.show()
# Out:
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 79ms/step

# %% [markdown]
# ## Save the Trained Model

# %%
model.save("Models/Model_Architecture(CS300-U).h5")
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %% [markdown]
# ## Full Real-Time Sample Inference Code:

# %%
from tensorflow.keras.models import load_model
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler

# Load trained model and scaler
model = load_model("Models/Model_Architecture(CS300-U).h5")

# Recreate scaler from training (you may save and load if needed)
# For now, assuming you have same StandardScaler object as training
scaler = StandardScaler()

# Use all training data to fit the scaler again
X_flat = X.reshape(-1, X.shape[-1])
scaler.fit(X_flat)
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# StandardScaler()

# %%
# Load real-time test sample
sample_df = pd.read_csv(r"Dataset\Harshit_Preprocessed_Data-CS300\Bitumin\001_Abj_Bitumin_1_12-2_part_001.csv")
sample = sample_df[['X_Acc', 'Y_Acc', 'Z_Acc', 'X_Gyro', 'Y_Gyro', 'Z_Gyro']].values
sample_scaled = scaler.transform(sample).reshape(1, 300, 6)

# Predict
prediction = model.predict(sample_scaled)
predicted_class = np.argmax(prediction)
reverse_map = {v: k for k, v in label_map.items()}
print("Predicted Road Type:", reverse_map[predicted_class])
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 220ms/step
# Predicted Road Type: Bitumin
