# %% [markdown]
# Since the dataset is now organized by label folders (Bitumin, Block, Concrete, Kankar) and each folder contains chunked CSVs, you're set for training a deep learning model. Let’s go step-by-step for building the model from this structure.

# %% [markdown]
# ## Step 1: Load and Prepare the Data

# %%
import os
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

# %% [markdown]
# # Harshit_Preprocessed_Data-CS250U

# %%
# Define base directory
base_dir = "Dataset/Harshit_Preprocessed_Data-CS250"

# Map folder names to class labels
label_map = {
    "Bitumin": 0,
    "Block": 1,
    "Concrete": 2,
    "Kanker": 3
}

X = []
y = []

# %%
# Iterate through each folder
for label_name, label in label_map.items():
    folder_path = os.path.join(base_dir, label_name)
    for file_name in os.listdir(folder_path):
        if file_name.endswith(".csv"):
            file_path = os.path.join(folder_path, file_name)
            try:
                df = pd.read_csv(file_path)
                # Ensure it has 200 rows and required columns
                if df.shape[0] == 250:
                    sample = df[['X_Acc', 'Y_Acc', 'Z_Acc', 'X_Gyro', 'Y_Gyro', 'Z_Gyro']].values
                    X.append(sample)
                    y.append(label)
            except Exception as e:
                print(f"Error reading {file_path}: {e}")

X = np.array(X)  # Shape: (samples, 200, 6)
y = np.array(y)

print("Loaded data shape:", X.shape, y.shape)
# Out:
# Loaded data shape: (1114, 250, 6) (1114,)

# %% [markdown]
# ## Step 2: Normalize and Split the Data

# %%
# Flatten and normalize
X_flat = X.reshape(-1, X.shape[-1])
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X_flat).reshape(X.shape)

# Train-test split
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.2, random_state=42, stratify=y)

# %% [markdown]
# ## Step 3: Define the LSTM Model

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout

# %%
model = Sequential([
    LSTM(64, return_sequences=True, input_shape=(250, 6)),
    Dropout(0.3),
    LSTM(32),
    Dense(32, activation='relu'),
    Dropout(0.3),
    Dense(4, activation='softmax')  # 4 output classes
])

model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
model.summary()
# Out:
# c:\Python312\Lib\site-packages\keras\src\layers\rnn\rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ lstm (LSTM)                     │ (None, 250, 64)        │        18,176 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 250, 64)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_1 (LSTM)                   │ (None, 32)             │        12,416 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 32)             │         1,056 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 32)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 4)              │           132 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 31,780 (124.14 KB)
#  Trainable params: 31,780 (124.14 KB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# ## Step 4: Train the Model

# %%
history = model.fit(X_train, y_train, epochs=30, batch_size=32, validation_data=(X_test, y_test))
# Out:
# Epoch 1/30
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 7s 109ms/step - accuracy: 0.3312 - loss: 1.3615 - val_accuracy: 0.3901 - val_loss: 1.2976
# Epoch 2/30
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 3s 100ms/step - accuracy: 0.4257 - loss: 1.2808 - val_accuracy: 0.4933 - val_loss: 1.1484
# Epoch 3/30
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 3s 98ms/step - accuracy: 0.5437 - loss: 1.0838 - val_accuracy: 0.5516 - val_loss: 1.0619
# Epoch 4/30
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 3s 110ms/step - accuracy: 0.6365 - loss: 0.9431 - val_accuracy: 0.6143 - val_loss: 0.9097
# Epoch 5/30
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 3s 118ms/step - accuracy: 0.6820 - loss: 0.7902 - val_accuracy: 0.6771 - val_loss: 0.7551
# Epoch 6/30
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 3s 112ms/step - accuracy: 0.7139 - loss: 0.7104 - val_accuracy: 0.7265 - val_loss: 0.7638
# Epoch 7/30
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 3s 108ms/step - accuracy: 0.7003 - loss: 0.7518 - val_accuracy: 0.6726 - val_loss: 0.8537
# Epoch 8/30
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 3s 113ms/step - accuracy: 0.7071 - loss: 0.8227 - val_accuracy: 0.6592 - val_loss: 0.8841
# Epoch 9/30
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 4s 134ms/step - accuracy: 0.7313 - loss: 0.7111 - val_accuracy: 0.7803 - val_loss: 0.6351
# Epoch 10/30
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 4s 132ms/step - accuracy: 0.7931 - loss: 0.6134 - val_accuracy: 0.7578 - val_loss: 0.7229
# Epoch 11/30
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 3s 123ms/step - accuracy: 0.7443 - loss: 0.7327 - val_accuracy: 0.8027 - val_loss: 0.6058
# Epoch 12/30
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 4s 138ms/step - accuracy: 0.7969 - loss: 0.6373 - val_accuracy: 0.7399 - val_loss: 0.8360
# Epoch 13/30
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 5s 161ms/step - accuracy: 0.7180 - loss: 0.7724 - val_accuracy: 0.7578 - val_loss: 0.6867
# Epoch 14/30
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 5s 180ms/step - accuracy: 0.8169 - loss: 0.5788 - val_accuracy: 0.8072 - val_loss: 0.6542
# Epoch 15/30
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 5s 167ms/step - accuracy: 0.8304 - loss: 0.4982 - val_accuracy: 0.8430 - val_loss: 0.5578
# Epoch 16/30
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 4s 152ms/step - accuracy: 0.8496 - loss: 0.5218 - val_accuracy: 0.7534 - val_loss: 0.7289
# Epoch 17/30
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 4s 146ms/step - accuracy: 0.8427 - loss: 0.5231 - val_accuracy: 0.8251 - val_loss: 0.6015
# Epoch 18/30
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 4s 158ms/step - accuracy: 0.8650 - loss: 0.4982 - val_accuracy: 0.8700 - val_loss: 0.4512
# Epoch 19/30
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 4s 138ms/step - accuracy: 0.9043 - loss: 0.3710 - val_accuracy: 0.8475 - val_loss: 0.5319
# Epoch 20/30
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 4s 142ms/step - accuracy: 0.8767 - loss: 0.4146 - val_accuracy: 0.8206 - val_loss: 0.5413
# Epoch 21/30
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 4s 156ms/step - accuracy: 0.8104 - loss: 0.5837 - val_accuracy: 0.7623 - val_loss: 0.6457
# Epoch 22/30
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 5s 175ms/step - accuracy: 0.8223 - loss: 0.4615 - val_accuracy: 0.7803 - val_loss: 0.5660
# Epoch 23/30
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 5s 161ms/step - accuracy: 0.8405 - loss: 0.4315 - val_accuracy: 0.8251 - val_loss: 0.5073
# Epoch 24/30
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 5s 168ms/step - accuracy: 0.8602 - loss: 0.4282 - val_accuracy: 0.6682 - val_loss: 0.8658
# Epoch 25/30
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 5s 186ms/step - accuracy: 0.7889 - loss: 0.6248 - val_accuracy: 0.7848 - val_loss: 0.6267
# Epoch 26/30
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 5s 172ms/step - accuracy: 0.8695 - loss: 0.4273 - val_accuracy: 0.8520 - val_loss: 0.4826
# Epoch 27/30
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 4s 155ms/step - accuracy: 0.8951 - loss: 0.3660 - val_accuracy: 0.8565 - val_loss: 0.4434
# Epoch 28/30
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 6s 178ms/step - accuracy: 0.9038 - loss: 0.3015 - val_accuracy: 0.8386 - val_loss: 0.5116
# Epoch 29/30
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 4s 144ms/step - accuracy: 0.8870 - loss: 0.4043 - val_accuracy: 0.8251 - val_loss: 0.6158
# Epoch 30/30
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 4s 148ms/step - accuracy: 0.8679 - loss: 0.4081 - val_accuracy: 0.8296 - val_loss: 0.4960

# %% [markdown]
# ## Step 5: Evaluate and Visualize Performance

# %%
import matplotlib.pyplot as plt

# Accuracy plot
plt.plot(history.history['accuracy'], label='Train Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.title('Model Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# Evaluate
loss, accuracy = model.evaluate(X_test, y_test)
print(f"Test Accuracy: {accuracy:.2f}")
# Out:
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 0.8332 - loss: 0.5208
# Test Accuracy: 0.83

# %% [markdown]
# ## Confusion Matrix

# %%
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay

y_pred = model.predict(X_test)
y_pred_classes = np.argmax(y_pred, axis=1)

cm = confusion_matrix(y_test, y_pred_classes)
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=label_map.keys())
disp.plot(cmap='Blues')
plt.show()
# Out:
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 160ms/step

# %% [markdown]
# ## Save the Trained Model

# %%
model.save("Models/Model_Architecture(CS250-U).h5")
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %% [markdown]
# ## Full Real-Time Sample Inference Code:

# %%
from tensorflow.keras.models import load_model
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler

# Load trained model and scaler
model = load_model("Models/Model_Architecture(CS250-U).h5")

# Recreate scaler from training (you may save and load if needed)
# For now, assuming you have same StandardScaler object as training
scaler = StandardScaler()

# Use all training data to fit the scaler again
X_flat = X.reshape(-1, X.shape[-1])
scaler.fit(X_flat)
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# StandardScaler()

# %%
# Load real-time test sample
sample_df = pd.read_csv(r"Dataset\Harshit_Preprocessed_Data-CS250\Bitumin\001_Abj_Bitumin_1_12-2_part_001.csv")
sample = sample_df[['X_Acc', 'Y_Acc', 'Z_Acc', 'X_Gyro', 'Y_Gyro', 'Z_Gyro']].values
sample_scaled = scaler.transform(sample).reshape(1, 250, 6)

# Predict
prediction = model.predict(sample_scaled)
predicted_class = np.argmax(prediction)
reverse_map = {v: k for k, v in label_map.items()}
print("Predicted Road Type:", reverse_map[predicted_class])
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# Predicted Road Type: Bitumin
